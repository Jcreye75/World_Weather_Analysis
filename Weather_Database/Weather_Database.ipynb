# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

# %%
# Create a new set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city using citipy for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | norman wells
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | maceio
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | husavik
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 1 | veere
# Processing Record 19 of Set 1 | balaipungut
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | nanma
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | valdivia
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | sao miguel
# Processing Record 29 of Set 1 | codrington
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | avera
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | kiruna
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | tongliao
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | margate
# Processing Record 42 of Set 1 | san quintin
# Processing Record 43 of Set 1 | hervey bay
# Processing Record 44 of Set 1 | fuling
# Processing Record 45 of Set 1 | gombong
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | tilichiki
# Processing Record 48 of Set 1 | yerbogachen
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | naustdal
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | ternate
# Processing Record 5 of Set 2 | the pas
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | hami
# Processing Record 8 of Set 2 | carutapera
# Processing Record 9 of Set 2 | mahon
# Processing Record 10 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | abapo
# Processing Record 14 of Set 2 | katsuura
# Processing Record 15 of Set 2 | berbera
# Processing Record 16 of Set 2 | kenai
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | arlit
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | segbwema
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | hamilton
# Processing Record 25 of Set 2 | maniitsoq
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | abu samrah
# Processing Record 28 of Set 2 | barguzin
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | dutse
# Processing Record 31 of Set 2 | yilan
# Processing Record 32 of Set 2 | moose factory
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | roald
# Processing Record 35 of Set 2 | coelho neto
# Processing Record 36 of Set 2 | asau
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 2 | diamantino
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | ixtapa
# Processing Record 45 of Set 2 | gazanjyk
# Processing Record 46 of Set 2 | grindavik
# Processing Record 47 of Set 2 | alta floresta
# Processing Record 48 of Set 2 | saint-augustin
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | shunyi
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | slavgorodskoye
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | mercedes
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | tiznit
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | batticaloa
# Processing Record 15 of Set 3 | naze
# Processing Record 16 of Set 3 | pemangkat
# Processing Record 17 of Set 3 | apatin
# Processing Record 18 of Set 3 | shakiso
# Processing Record 19 of Set 3 | walvis bay
# Processing Record 20 of Set 3 | gigmoto
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | salihorsk
# Processing Record 23 of Set 3 | ocos
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | yulara
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | jasdan
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | salur
# Processing Record 38 of Set 3 | caravelas
# Processing Record 39 of Set 3 | rock springs
# Processing Record 40 of Set 3 | esteli
# Processing Record 41 of Set 3 | saurimo
# Processing Record 42 of Set 3 | niteroi
# Processing Record 43 of Set 3 | atar
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | buala
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | port lincoln
# Processing Record 48 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | amalapuram
# Processing Record 1 of Set 4 | tres arroyos
# Processing Record 2 of Set 4 | englewood
# Processing Record 3 of Set 4 | biak
# Processing Record 4 of Set 4 | lakatoro
# Processing Record 5 of Set 4 | mayo
# Processing Record 6 of Set 4 | clyde river
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | santa isabel do rio negro
# Processing Record 9 of Set 4 | gamba
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 4 | balakirevo
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | filadelfia
# Processing Record 15 of Set 4 | tigil
# Processing Record 16 of Set 4 | sidi ali
# Processing Record 17 of Set 4 | moratuwa
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | erzin
# Processing Record 21 of Set 4 | marawi
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | namatanai
# Processing Record 25 of Set 4 | karratha
# Processing Record 26 of Set 4 | lashio
# Processing Record 27 of Set 4 | wanlaweyn
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | nelson bay
# Processing Record 31 of Set 4 | rasulnagar
# Processing Record 32 of Set 4 | kushmurun
# Processing Record 33 of Set 4 | nokaneng
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | bardiyah
# Processing Record 37 of Set 4 | marsh harbour
# Processing Record 38 of Set 4 | erpeli
# Processing Record 39 of Set 4 | atbasar
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | adrar
# Processing Record 42 of Set 4 | labytnangi
# Processing Record 43 of Set 4 | bilma
# Processing Record 44 of Set 4 | salaya
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | broken hill
# Processing Record 47 of Set 4 | grand gaube
# Processing Record 48 of Set 4 | pekan
# Processing Record 49 of Set 4 | warrington
# Processing Record 50 of Set 4 | tonekabon
# Processing Record 1 of Set 5 | jinxiang
# Processing Record 2 of Set 5 | narsaq
# Processing Record 3 of Set 5 | taldan
# Processing Record 4 of Set 5 | alyangula
# Processing Record 5 of Set 5 | joshimath
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | marienburg
# Processing Record 8 of Set 5 | pathein
# Processing Record 9 of Set 5 | chicama
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | isla mujeres
# Processing Record 12 of Set 5 | castro
# Processing Record 13 of Set 5 | toora-khem
# Processing Record 14 of Set 5 | lompoc
# Processing Record 15 of Set 5 | gilazi
# City not found. Skipping...
# Processing Record 16 of Set 5 | kupang
# Processing Record 17 of Set 5 | takoradi
# Processing Record 18 of Set 5 | aswan
# Processing Record 19 of Set 5 | atasu
# Processing Record 20 of Set 5 | sept-iles
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 5 | rabo de peixe
# Processing Record 24 of Set 5 | eyl
# Processing Record 25 of Set 5 | qaanaaq
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | hirado
# Processing Record 28 of Set 5 | manyana
# Processing Record 29 of Set 5 | providencia
# Processing Record 30 of Set 5 | pontal do parana
# Processing Record 31 of Set 5 | longyearbyen
# Processing Record 32 of Set 5 | atuona
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | joura
# Processing Record 35 of Set 5 | korla
# Processing Record 36 of Set 5 | boyolangu
# Processing Record 37 of Set 5 | olinda
# Processing Record 38 of Set 5 | honiara
# Processing Record 39 of Set 5 | tiksi
# Processing Record 40 of Set 5 | potgietersrus
# City not found. Skipping...
# Processing Record 41 of Set 5 | merauke
# Processing Record 42 of Set 5 | dubbo
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | russell
# Processing Record 45 of Set 5 | san blas
# Processing Record 46 of Set 5 | jiuquan
# Processing Record 47 of Set 5 | lavrentiya
# Processing Record 48 of Set 5 | kokkola
# Processing Record 49 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | maumere
# Processing Record 1 of Set 6 | bubaque
# Processing Record 2 of Set 6 | sioux lookout
# Processing Record 3 of Set 6 | haines junction
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | itoman
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | waipawa
# Processing Record 8 of Set 6 | teknaf
# Processing Record 9 of Set 6 | barrow
# Processing Record 10 of Set 6 | komsomolskiy
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | sikandarpur
# Processing Record 13 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | pokhara
# Processing Record 18 of Set 6 | presque isle
# Processing Record 19 of Set 6 | susehri
# Processing Record 20 of Set 6 | vasterhaninge
# Processing Record 21 of Set 6 | khakhea
# Processing Record 22 of Set 6 | caraballeda
# Processing Record 23 of Set 6 | krishnarajpet
# Processing Record 24 of Set 6 | sabang
# Processing Record 25 of Set 6 | kindu
# Processing Record 26 of Set 6 | tuatapere
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | lamego
# Processing Record 29 of Set 6 | uthai thani
# Processing Record 30 of Set 6 | porto novo
# Processing Record 31 of Set 6 | nuevitas
# Processing Record 32 of Set 6 | hirara
# Processing Record 33 of Set 6 | prince rupert
# Processing Record 34 of Set 6 | shache
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | axim
# Processing Record 37 of Set 6 | ketchikan
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | bezhetsk
# Processing Record 40 of Set 6 | bonthe
# Processing Record 41 of Set 6 | cao bang
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | dobryatino
# Processing Record 44 of Set 6 | batagay-alyta
# Processing Record 45 of Set 6 | qinhuangdao
# Processing Record 46 of Set 6 | gawler
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | bend
# Processing Record 49 of Set 6 | vicksburg
# Processing Record 50 of Set 6 | lady frere
# Processing Record 1 of Set 7 | umba
# Processing Record 2 of Set 7 | yoichi
# Processing Record 3 of Set 7 | siva
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | kodiak
# Processing Record 6 of Set 7 | rocha
# Processing Record 7 of Set 7 | nyurba
# Processing Record 8 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 7 | vostok
# Processing Record 10 of Set 7 | san angelo
# Processing Record 11 of Set 7 | mahibadhoo
# Processing Record 12 of Set 7 | westport
# Processing Record 13 of Set 7 | ribas do rio pardo
# Processing Record 14 of Set 7 | saint-raphael
# Processing Record 15 of Set 7 | pemba
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | gat
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | coquimbo
# Processing Record 20 of Set 7 | manokwari
# Processing Record 21 of Set 7 | ewa beach
# Processing Record 22 of Set 7 | chaa-khol
# City not found. Skipping...
# Processing Record 23 of Set 7 | harper
# Processing Record 24 of Set 7 | ilheus
# Processing Record 25 of Set 7 | vestmannaeyjar
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 7 | oum hadjer
# Processing Record 29 of Set 7 | kardasova recice
# Processing Record 30 of Set 7 | miandrivazo
# Processing Record 31 of Set 7 | morant bay
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | anadyr
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | vardo
# Processing Record 36 of Set 7 | touros
# Processing Record 37 of Set 7 | dembi dolo
# Processing Record 38 of Set 7 | marrakesh
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | warrnambool
# Processing Record 41 of Set 7 | beyla
# Processing Record 42 of Set 7 | vera cruz
# Processing Record 43 of Set 7 | sorland
# Processing Record 44 of Set 7 | qinzhou
# Processing Record 45 of Set 7 | palana
# Processing Record 46 of Set 7 | san isidro
# Processing Record 47 of Set 7 | turukhansk
# Processing Record 48 of Set 7 | caconda
# Processing Record 49 of Set 7 | dudinka
# Processing Record 50 of Set 7 | camana
# Processing Record 1 of Set 8 | chuy
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | rio gallegos
# Processing Record 4 of Set 8 | port-cartier
# Processing Record 5 of Set 8 | olafsvik
# Processing Record 6 of Set 8 | kilakarai
# Processing Record 7 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | ulaanbaatar
# Processing Record 10 of Set 8 | monte alegre de sergipe
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | williston
# Processing Record 14 of Set 8 | kandrian
# Processing Record 15 of Set 8 | puerto madryn
# Processing Record 16 of Set 8 | crawfordsville
# Processing Record 17 of Set 8 | roebourne
# Processing Record 18 of Set 8 | sarankhola
# Processing Record 19 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 8 | chiredzi
# Processing Record 21 of Set 8 | cheremukhovo
# Processing Record 22 of Set 8 | ziro
# Processing Record 23 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 8 | potosi
# Processing Record 25 of Set 8 | houma
# Processing Record 26 of Set 8 | waru
# Processing Record 27 of Set 8 | bokovskaya
# Processing Record 28 of Set 8 | ko samui
# Processing Record 29 of Set 8 | aripuana
# Processing Record 30 of Set 8 | tautira
# Processing Record 31 of Set 8 | mahebourg
# Processing Record 32 of Set 8 | ust-omchug
# Processing Record 33 of Set 8 | svetlyy
# Processing Record 34 of Set 8 | cayenne
# Processing Record 35 of Set 8 | kvarkeno
# Processing Record 36 of Set 8 | lima
# Processing Record 37 of Set 8 | maracacume
# Processing Record 38 of Set 8 | kavant
# City not found. Skipping...
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | manjacaze
# Processing Record 41 of Set 8 | guangyuan
# Processing Record 42 of Set 8 | manta
# Processing Record 43 of Set 8 | severnoye
# Processing Record 44 of Set 8 | am timan
# Processing Record 45 of Set 8 | sakakah
# Processing Record 46 of Set 8 | atherton
# Processing Record 47 of Set 8 | umm lajj
# Processing Record 48 of Set 8 | doha
# Processing Record 49 of Set 8 | kadiri
# Processing Record 50 of Set 8 | kieta
# Processing Record 1 of Set 9 | barbosa ferraz
# Processing Record 2 of Set 9 | shimoda
# Processing Record 3 of Set 9 | bunia
# Processing Record 4 of Set 9 | tower
# Processing Record 5 of Set 9 | verkhovazhye
# Processing Record 6 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 9 | acarau
# Processing Record 8 of Set 9 | laguna
# Processing Record 9 of Set 9 | pacific grove
# Processing Record 10 of Set 9 | cururupu
# Processing Record 11 of Set 9 | znamenskoye
# Processing Record 12 of Set 9 | ardmore
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | bara
# Processing Record 15 of Set 9 | belyy yar
# Processing Record 16 of Set 9 | gravdal
# Processing Record 17 of Set 9 | ngunguru
# Processing Record 18 of Set 9 | fort-shevchenko
# Processing Record 19 of Set 9 | wufeng
# Processing Record 20 of Set 9 | svetlaya
# Processing Record 21 of Set 9 | juruti
# Processing Record 22 of Set 9 | emerald
# Processing Record 23 of Set 9 | nipawin
# Processing Record 24 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 9 | amot
# Processing Record 27 of Set 9 | kajaani
# Processing Record 28 of Set 9 | pitimbu
# Processing Record 29 of Set 9 | shieli
# Processing Record 30 of Set 9 | gao
# Processing Record 31 of Set 9 | isla vista
# Processing Record 32 of Set 9 | sangar
# Processing Record 33 of Set 9 | dicabisagan
# Processing Record 34 of Set 9 | constitucion
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | bournemouth
# Processing Record 37 of Set 9 | dzhebariki-khaya
# Processing Record 38 of Set 9 | chara
# Processing Record 39 of Set 9 | tual
# Processing Record 40 of Set 9 | yarim
# Processing Record 41 of Set 9 | shumskiy
# Processing Record 42 of Set 9 | ransang
# Processing Record 43 of Set 9 | lagos
# Processing Record 44 of Set 9 | cam ranh
# Processing Record 45 of Set 9 | ossora
# Processing Record 46 of Set 9 | apricena
# Processing Record 47 of Set 9 | zapolyarnyy
# Processing Record 48 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 9 | kumluca
# Processing Record 50 of Set 9 | port lavaca
# Processing Record 1 of Set 10 | aden
# Processing Record 2 of Set 10 | enshi
# Processing Record 3 of Set 10 | benguela
# Processing Record 4 of Set 10 | san ramon
# Processing Record 5 of Set 10 | plettenberg bay
# Processing Record 6 of Set 10 | glossa
# Processing Record 7 of Set 10 | andenes
# Processing Record 8 of Set 10 | bulgan
# Processing Record 9 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 10 | cochrane
# Processing Record 11 of Set 10 | yokadouma
# Processing Record 12 of Set 10 | tairua
# Processing Record 13 of Set 10 | karanganyar
# Processing Record 14 of Set 10 | beringovskiy
# Processing Record 15 of Set 10 | la asuncion
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | riyadh
# Processing Record 18 of Set 10 | katha
# City not found. Skipping...
# Processing Record 19 of Set 10 | taltal
# Processing Record 20 of Set 10 | contamana
# Processing Record 21 of Set 10 | qasigiannguit
# Processing Record 22 of Set 10 | shakawe
# Processing Record 23 of Set 10 | launceston
# Processing Record 24 of Set 10 | atlantic city
# Processing Record 25 of Set 10 | nome
# Processing Record 26 of Set 10 | omsukchan
# Processing Record 27 of Set 10 | tornio
# Processing Record 28 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 10 | west wendover
# Processing Record 32 of Set 10 | yaan
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | calvinia
# Processing Record 36 of Set 10 | mindelo
# Processing Record 37 of Set 10 | praia da vitoria
# Processing Record 38 of Set 10 | itainopolis
# Processing Record 39 of Set 10 | sterling
# Processing Record 40 of Set 10 | mitsamiouli
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 10 | sorong
# Processing Record 44 of Set 10 | terrace
# Processing Record 45 of Set 10 | novoasbest
# Processing Record 46 of Set 10 | agnibilekrou
# Processing Record 47 of Set 10 | sisophon
# Processing Record 48 of Set 10 | bacabal
# Processing Record 49 of Set 10 | kunya
# Processing Record 50 of Set 10 | galdar
# Processing Record 1 of Set 11 | dunedin
# Processing Record 2 of Set 11 | suslovo
# Processing Record 3 of Set 11 | bahia blanca
# Processing Record 4 of Set 11 | vilhena
# Processing Record 5 of Set 11 | port augusta
# Processing Record 6 of Set 11 | manicore
# Processing Record 7 of Set 11 | dali
# Processing Record 8 of Set 11 | enugu
# Processing Record 9 of Set 11 | coracora
# Processing Record 10 of Set 11 | labuhan
# Processing Record 11 of Set 11 | nioki
# Processing Record 12 of Set 11 | lekoni
# Processing Record 13 of Set 11 | trincomalee
# Processing Record 14 of Set 11 | makurdi
# Processing Record 15 of Set 11 | bengkulu
# Processing Record 16 of Set 11 | moba
# Processing Record 17 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 11 | itatskiy
# Processing Record 19 of Set 11 | whitianga
# Processing Record 20 of Set 11 | muvattupula
# Processing Record 21 of Set 11 | hambantota
# Processing Record 22 of Set 11 | sistranda
# Processing Record 23 of Set 11 | pula
# Processing Record 24 of Set 11 | slave lake
# Processing Record 25 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 26 of Set 11 | juneau
# Processing Record 27 of Set 11 | saint-jean-de-braye
# Processing Record 28 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 11 | kuytun
# Processing Record 30 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 31 of Set 11 | saint-pierre
# Processing Record 32 of Set 11 | hay river
# Processing Record 33 of Set 11 | potanino
# Processing Record 34 of Set 11 | santa cruz
# Processing Record 35 of Set 11 | dingle
# Processing Record 36 of Set 11 | kabalo
# Processing Record 37 of Set 11 | espanola
# Processing Record 38 of Set 11 | borogontsy
# Processing Record 39 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 40 of Set 11 | lumeje
# Processing Record 41 of Set 11 | gacko
# Processing Record 42 of Set 11 | sechura
# Processing Record 43 of Set 11 | baykit
# Processing Record 44 of Set 11 | itarema
# Processing Record 45 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | aykino
# Processing Record 48 of Set 11 | christchurch
# Processing Record 49 of Set 11 | monkey bay
# Processing Record 50 of Set 11 | bhaderwah
# Processing Record 1 of Set 12 | vilyuysk
# Processing Record 2 of Set 12 | makasar
# Processing Record 3 of Set 12 | uray
# Processing Record 4 of Set 12 | nachingwea
# Processing Record 5 of Set 12 | ambon
# Processing Record 6 of Set 12 | ust-maya
# Processing Record 7 of Set 12 | teeli
# Processing Record 8 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 12 | meulaboh
# Processing Record 10 of Set 12 | ishikawa
# Processing Record 11 of Set 12 | tazovskiy
# Processing Record 12 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 12 | shenjiamen
# Processing Record 14 of Set 12 | fomboni
# Processing Record 15 of Set 12 | nishihara
# Processing Record 16 of Set 12 | mbandaka
# Processing Record 17 of Set 12 | mancio lima
# Processing Record 18 of Set 12 | akyab
# Processing Record 19 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 12 | surin
# Processing Record 21 of Set 12 | vigrestad
# Processing Record 22 of Set 12 | bandarbeyla
# Processing Record 23 of Set 12 | maltahohe
# Processing Record 24 of Set 12 | abalak
# Processing Record 25 of Set 12 | sergeyevka
# Processing Record 26 of Set 12 | kizhinga
# Processing Record 27 of Set 12 | katobu
# Processing Record 28 of Set 12 | salina
# Processing Record 29 of Set 12 | inirida
# Processing Record 30 of Set 12 | manzhouli
# Processing Record 31 of Set 12 | general roca
# Processing Record 32 of Set 12 | bonavista
# Processing Record 33 of Set 12 | totton
# Processing Record 34 of Set 12 | kathmandu
# Processing Record 35 of Set 12 | inuvik
# Processing Record 36 of Set 12 | volchikha
# Processing Record 37 of Set 12 | pozarevac
# Processing Record 38 of Set 12 | blyth
# Processing Record 39 of Set 12 | dedovichi
# Processing Record 40 of Set 12 | arequipa
# Processing Record 41 of Set 12 | kaeo
# Processing Record 42 of Set 12 | gazojak
# Processing Record 43 of Set 12 | bud
# Processing Record 44 of Set 12 | tskneti
# Processing Record 45 of Set 12 | klaksvik
# Processing Record 46 of Set 12 | chernushka
# Processing Record 47 of Set 12 | leh
# Processing Record 48 of Set 12 | oktyabrskoye
# Processing Record 49 of Set 12 | ormara
# Processing Record 50 of Set 12 | san andres
# Processing Record 1 of Set 13 | bambanglipuro
# Processing Record 2 of Set 13 | chik
# Processing Record 3 of Set 13 | belomorsk
# Processing Record 4 of Set 13 | evensk
# Processing Record 5 of Set 13 | japura
# Processing Record 6 of Set 13 | tralee
# Processing Record 7 of Set 13 | saint anthony
# Processing Record 8 of Set 13 | verkhoyansk
# Processing Record 9 of Set 13 | carlos chagas
# Processing Record 10 of Set 13 | rehoboth
# Processing Record 11 of Set 13 | midlothian
# Processing Record 12 of Set 13 | sinnamary
# Processing Record 13 of Set 13 | napier
# Processing Record 14 of Set 13 | salalah
# Processing Record 15 of Set 13 | mariestad
# Processing Record 16 of Set 13 | villa carlos paz
# Processing Record 17 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 13 | hibbing
# Processing Record 19 of Set 13 | camacha
# Processing Record 20 of Set 13 | xian
# Processing Record 21 of Set 13 | maningrida
# Processing Record 22 of Set 13 | luanda
# Processing Record 23 of Set 13 | burnie
# Processing Record 24 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 25 of Set 13 | tommot
# Processing Record 26 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 13 | semirom
# Processing Record 29 of Set 13 | baie-comeau
# Processing Record 30 of Set 13 | aquiraz
# Processing Record 31 of Set 13 | san juan de los morros
# Processing Record 32 of Set 13 | moindou
# Processing Record 33 of Set 13 | griffith
# Processing Record 34 of Set 13 | flin flon
# Processing Record 35 of Set 13 | ayan
# Processing Record 36 of Set 13 | pafos
# Processing Record 37 of Set 13 | aleppo
# Processing Record 38 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 13 | ambilobe
# Processing Record 40 of Set 13 | okhotsk
# Processing Record 41 of Set 13 | beira
# Processing Record 42 of Set 13 | fort nelson
# Processing Record 43 of Set 13 | marsa matruh
# Processing Record 44 of Set 13 | oriximina
# Processing Record 45 of Set 13 | kletskaya
# Processing Record 46 of Set 13 | uhingen
# Processing Record 47 of Set 13 | gornyy
# Processing Record 48 of Set 13 | vila franca do campo
# Processing Record 49 of Set 13 | laurel
# Processing Record 50 of Set 13 | cockburn town
# Processing Record 1 of Set 14 | strelka
# Processing Record 2 of Set 14 | bac lieu
# Processing Record 3 of Set 14 | saint-francois
# Processing Record 4 of Set 14 | ilo
# Processing Record 5 of Set 14 | beaverlodge
# Processing Record 6 of Set 14 | mandan
# Processing Record 7 of Set 14 | pavilosta
# Processing Record 8 of Set 14 | milkovo
# Processing Record 9 of Set 14 | kununurra
# Processing Record 10 of Set 14 | sarangani
# Processing Record 11 of Set 14 | kholodnyy
# Processing Record 12 of Set 14 | aleksandrovka
# Processing Record 13 of Set 14 | tselinnoye
# Processing Record 14 of Set 14 | san patricio
# Processing Record 15 of Set 14 | pasni
# Processing Record 16 of Set 14 | belaya gora
# Processing Record 17 of Set 14 | malpe
# Processing Record 18 of Set 14 | pareora
# Processing Record 19 of Set 14 | morro bay
# Processing Record 20 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 14 | yakeshi
# Processing Record 22 of Set 14 | santa fe
# Processing Record 23 of Set 14 | vao
# Processing Record 24 of Set 14 | comodoro rivadavia
# Processing Record 25 of Set 14 | chuncheng
# Processing Record 26 of Set 14 | jiayuguan
# Processing Record 27 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 14 | mandla
# Processing Record 29 of Set 14 | barra patuca
# Processing Record 30 of Set 14 | maturin
# Processing Record 31 of Set 14 | zeya
# Processing Record 32 of Set 14 | bontang
# Processing Record 33 of Set 14 | mackay
# Processing Record 34 of Set 14 | carmen
# Processing Record 35 of Set 14 | zhob
# Processing Record 36 of Set 14 | alice springs
# Processing Record 37 of Set 14 | ekibastuz
# Processing Record 38 of Set 14 | fabrica
# Processing Record 39 of Set 14 | lampa
# Processing Record 40 of Set 14 | jackson
# Processing Record 41 of Set 14 | nowa sol
# Processing Record 42 of Set 14 | srednekolymsk
# Processing Record 43 of Set 14 | nuevo progreso
# Processing Record 44 of Set 14 | punalur
# Processing Record 45 of Set 14 | carauari
# Processing Record 46 of Set 14 | santa rita do sapucai
# Processing Record 47 of Set 14 | esmeraldas
# Processing Record 48 of Set 14 | paralimni
# Processing Record 49 of Set 14 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 50 of Set 14 | peniche
# Processing Record 1 of Set 15 | jacksonville
# Processing Record 2 of Set 15 | namibe
# Processing Record 3 of Set 15 | murud
# Processing Record 4 of Set 15 | yumen
# Processing Record 5 of Set 15 | la romana
# Processing Record 6 of Set 15 | green valley
# Processing Record 7 of Set 15 | bereda
# Processing Record 8 of Set 15 | nhulunbuy
# Processing Record 9 of Set 15 | port-gentil
# Processing Record 10 of Set 15 | oytal
# Processing Record 11 of Set 15 | rovenki
# Processing Record 12 of Set 15 | kaffrine
# Processing Record 13 of Set 15 | kedrovyy
# Processing Record 14 of Set 15 | esperantina
# Processing Record 15 of Set 15 | dongsheng
# Processing Record 16 of Set 15 | deputatskiy
# Processing Record 17 of Set 15 | bom jesus
# Processing Record 18 of Set 15 | ilulissat
# Processing Record 19 of Set 15 | hualmay
# Processing Record 20 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 21 of Set 15 | tukan
# Processing Record 22 of Set 15 | elektrenai
# Processing Record 23 of Set 15 | fujinomiya
# Processing Record 24 of Set 15 | lagoa
# Processing Record 25 of Set 15 | dalnerechensk
# Processing Record 26 of Set 15 | beloha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     46.06        71           0
# 1     Esperance      AU -33.8667  121.9000     73.24        44         100
# 2    Butaritari      KI   3.0707  172.7902     81.81        76           1
# 3       Rikitea      PF -23.1203 -134.9692     73.08        78         100
# 4        Hobart      AU -42.8794  147.3294     63.01        57          75
# 5  Norman Wells      CA  65.2820 -126.8329     23.04        93          75
# 6   Port Alfred      ZA -33.5906   26.8910     66.06        81         100
# 7    Georgetown      MY   5.4112  100.3354     79.90        89          20
# 8        Maceio      BR  -9.6658  -35.7353     76.44        94          20
# 9         Vaini      TO -21.2000 -175.2000     82.56        78          75
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       15.21     overcast clouds
# 2       11.54          light rain
# 3       17.69     overcast clouds
# 4        3.00       broken clouds
# 5        0.00       broken clouds
# 6       15.08     overcast clouds
# 7        3.00          few clouds
# 8        5.75          few clouds
# 9       10.36       broken clouds

# %%
 # Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
